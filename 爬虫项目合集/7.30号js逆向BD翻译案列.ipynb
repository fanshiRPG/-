# %%
import requests
import time
import execjs

url='https://fanyi.baidu.com/#en/zh/python'
text=execjs.compile(open('demo.js').read())
sign=text.call('b','python')
ts=int(time.time()*1000)
headers={
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36 SLBrowser/9.0.3.5211 SLBChan/105',
    'Referer':'https://fanyi.baidu.com/',
    'Cookie':'BAIDUID=F64A1A63F9CB6A87DCD8847E4CE64DF1:FG=1; PSTM=1721956469; H_PS_PSSID=60272_60452_60465_60492_60498_60525; BIDUPSID=3D16C4383584E22855CBD68481161FFC; BDORZ=FFFB88E999055A3F8A630C64834BD6D0; H_WISE_SIDS=60272_60452_60465_60492_60498_60525; BAIDUID_BFESS=F64A1A63F9CB6A87DCD8847E4CE64DF1:FG=1; ZFY=4B62BarPPKycRZViEZL:BQyQK8Ub8mISVQloYKfxq9u0:C; H_WISE_SIDS_BFESS=60272_60452_60465_60492_60498_60525; BDRCVFR[A7hGrXFW48R]=mk3SLVN4HKm; delPer=0; PSINO=3; BA_HECTOR=840g042h0481802l0l8l84203afqap1jagdd11u; ppfuid=...; smallFlowVersion=old; RT="z=1&dm=baidu.com&si=645d5462-b987-4ebd-8b52-340194f233c2&ss=lz7q079t&sl=a&tt=3flt&bcn=https%3A%2F%2Ffclog.baidu.com%2Flog%2Fweirwood%3Ftype%3Dperf&ld=flnv&nu=9y8m6cy&cl=fnj1&ul=hw0q&hd=hwgm"; Hm_lvt_64ecd82404c51e03dc91cb9e8c025574=1722302606; Hm_lpvt_64ecd82404c51e03dc91cb9e8c025574=1722302606; REALTIME_TRANS_SWITCH=1; FANYI_WORD_SWITCH=1; HISTORY_SWITCH=1; SOUND_SPD_SWITCH=1; SOUND_PREFER_SWITCH=1; ab_sr=1.0.1_NDExYmQ3Y2NjYTMzMTMwNzYyMGQ1OWYwMmYwOGQ5MDAzZDVhZTZjZmM2NGNlMTQ1ZjU3ZmMxZjc1NmI4MWY2ZDdlNTNmYmRkM2NiMjE1ZjE1OGY5YTY5MTg2NDU3OGM2NTUzOGE0MTdjYzA5MzAxMmRkMmVmMDE1ZjQ5MmU1MzM0N2EyZDRiMjFmZWM0OGE2NTUyODJhN2ZjZGNjYmIwYg=='
}
params={
    'from':'en',
    'to':'zh',
    'query':'p',
    'transtype':'realtime',
    'simple_means_flag':3,
    'sign':sign,                       #此处需要逆向分析出数据出处
    'token':'dc00867587dde0d80c8f76b66977695f',
    'domain':'common',
    'ts':ts)                  #此处利用time库构建时间戳
}

resp=requests.post(url,headers=headers,data=params)
resp.text
# Out:
# '<!DOCTYPE html>\n<html>\n    <head>\n        <meta charset="utf-8">\n        <!--IE内核浏览器，强制使用用户已安装的最高版本浏览器渲染，有Chrome框架的优先使用Chrome框架-->\n        <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n        <title>百度翻译-200种语言互译、沟通全世界！</title>\n        <meta name="keywords" content="翻译,在线翻译,文档翻译,网页翻译,百度翻译,词典">\n        <meta name="description" content="百度翻译提供即时免费200+语言翻译服务，拥有网页、APP、API产品，支持文本翻译、文档翻译、图片翻译等特色功能，满足用户查词翻译、文献翻译、合同翻译等需求，随时随地沟通全世界">\n        <!--强制国内双核浏览器使用Webkit内核渲染页面-->\n        <!--360 6.X 以上可识别-->\n        <meta name="renderer" content="webkit">\n        <!--其他双核可识别-->\n        <meta name="force-rendering" content="webkit">\n        <script>\n        function checkFromBdSearch() {\n            return document.referrer && document.referrer.includes(\'www.baidu.com\');\n        };\n\n        function checkHomeFromAladdin() {\n            return checkFromBdSearch() && location.search.includes(\'aldtype\');\n        };\n\n        function dealExtChannelOnFirstRende
# ...
